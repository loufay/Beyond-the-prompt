# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %%
df = pd.read_csv('/mnt/data2/datasets_lfay/MedImageInsights/Visualization/Data/vindr_prediction_changes.csv')

# %%
class_p = 0
filtered_df = df[(df['Pneumonia'] == class_p) & (df['Prediction_zeroshot'] == class_p) & (df['Prediction_vte'] == class_p)]
len(filtered_df)
# Out:
# 58

# %%
PATH_TO_DATA = "/mnt/data2/datasets_lfay/MedImageInsights/data"
# get Path of first image
i=0
path_vindr_x = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr_x
print(path_vindr)
# copy image to /mnt/data2/datasets_lfay/test
import shutil

# Copy the image
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+str(class_p)+"/"+path_vindr_x.split('/')[-1])


img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')


i=1
path_vindr_x = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr_x
print(path_vindr)
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+str(class_p)+"/"+path_vindr_x.split('/')[-1])

img1 = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img1, cmap='gray')
plt.axis('off')

i=3
path_vindr_x = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr_x
print(path_vindr)
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+str(class_p)+"/"+path_vindr_x.split('/')[-1])

img = Image.open(path_vindr)
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
# Out:
# /mnt/data2/datasets_lfay/MedImageInsights/data/vindr-pcxr/1.0.0/test/7a391ba5ce608197fbf983bf4e7be313.jpg
# /mnt/data2/datasets_lfay/MedImageInsights/data/vindr-pcxr/1.0.0/test/fddce52f8389178ae1cd10c1d0d7e7d8.jpg
# /mnt/data2/datasets_lfay/MedImageInsights/data/vindr-pcxr/1.0.0/test/59f2408f3fddd5d286404d79929db522.jpg
# (-0.5, 1565.5, 2083.5, -0.5)

# %%
img1==img
# Out:
# False

# %%
filtered_df = df[(df['Pneumonia'] == 1) & (df['Prediction_zeroshot'] == 1) & (df['Prediction_vte'] == 1)]

# %%
PATH_TO_DATA = "/mnt/data2/datasets_lfay/MedImageInsights/data"
# get Path of first image
i=0
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')


i=1
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')

i=2
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr)
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1250.5, 1476.5, -0.5)

# %%
df = pd.read_csv('/mnt/data2/datasets_lfay/MedImageInsights/Visualization/Data/chexpert_prediction_changes.csv')

# %%
class_p = 1
filtered_df = df[(df['Pneumonia'] == class_p) & (df['Prediction_zeroshot'] == class_p) & (df['Prediction_vte'] == class_p)]
len(filtered_df)
# Out:
# 346

# %%
PATH_TO_DATA = "/mnt/data2/datasets_lfay/MedImageInsights/data"
class_p = str(class_p)
# get Path of first image
i=0
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"chexpert/"+class_p+"/"+path_vindr.split('/')[-3]+path_vindr.split('/')[-2]+path_vindr.split('/')[-1])


i=1
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"chexpert/"+class_p+"/"+path_vindr.split('/')[-3]+path_vindr.split('/')[-2]+path_vindr.split('/')[-1])

i=4
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"chexpert/"+class_p+"/"+path_vindr.split('/')[-3]+path_vindr.split('/')[-2]+path_vindr.split('/')[-1])
# Out:
# '/mnt/data2/datasets_lfay/test/chexpert/1/patient54014study1view1_frontal.jpg'

# %%
filtered_df = df[(df['Pneumonia'] == 1) & (df['Prediction_zeroshot'] == 0) & (df['Prediction_vte'] == 1)]

PATH_TO_DATA = "/mnt/data2/datasets_lfay/MedImageInsights/data"
# get Path of first image
i=18
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"chexpert_pneumonia_"+path_vindr_x.split('/')[-1])
# Out:
# '/mnt/data2/datasets_lfay/test/chexpert_pneumonia_b3c3e512a0d4705ec882e66d09628a92.jpg'

# %%
df = pd.read_csv('/mnt/data2/datasets_lfay/MedImageInsights/Visualization/Data/mimic_prediction_changes.csv')

# %%
class_p = 0
filtered_df = df[(df['Pneumonia'] == class_p) & (df['Prediction_zeroshot'] == class_p) & (df['Prediction_vte'] == class_p)]
len(filtered_df)
# Out:
# 3552

# %%
PATH_TO_DATA = "/mnt/data2/datasets_lfay/MedImageInsights/data"
class_p = str(class_p)
# get Path of first image
i=0
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"mimic/"+class_p+"/"+path_vindr.split('/')[-3]+path_vindr.split('/')[-2]+path_vindr.split('/')[-1])


i=1
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"mimic/"+class_p+"/"+path_vindr.split('/')[-3]+path_vindr.split('/')[-2]+path_vindr.split('/')[-1])

i=4
path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')
shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"mimic/"+class_p+"/"+path_vindr.split('/')[-3]+path_vindr.split('/')[-2]+path_vindr.split('/')[-1])
# Out:
# '/mnt/data2/datasets_lfay/test/mimic/0/p11604900s595370359449e838-f1a44623-bc6aff17-86315208-9fe11134.jpg'

# %%
filtered_df = df[(df['Pneumonia'] == 1) & (df['Prediction_zeroshot'] == 0) & (df['Prediction_vte'] == 1)]

PATH_TO_DATA = "/mnt/data2/datasets_lfay/MedImageInsights/data"
# get Path of first image
i=12

path_vindr = filtered_df.iloc[i]['Path']
path_vindr = PATH_TO_DATA + path_vindr
img = Image.open(path_vindr).convert("L")
plt.figure()
plt.imshow(img, cmap='gray')
plt.axis('off')

shutil.copy(path_vindr, "/mnt/data2/datasets_lfay/test/"+"mimic_pneumonia_"+path_vindr_x.split('/')[-1])
# Out:
# '/mnt/data2/datasets_lfay/test/mimic_pneumonia_b3c3e512a0d4705ec882e66d09628a92.jpg'
